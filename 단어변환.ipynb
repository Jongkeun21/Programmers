# %%
begin = "hit"
target = "cog"
words = ["hot", "dot", "dog", "lot", "log", "cog"]

# %%
words.insert(0, begin)
# if not target in words => return 0

# %%
print(words)
# Out:
# ['hit', 'hot', 'dot', 'dog', 'lot', 'log', 'cog']

# %%
graph = [[] for col in range(len(words))]
for i in range(len(words)) :
    print("===================================")
    print("words[i]: ", words[i])
    for j in range(len(words)) :
        print("words[j]: ", words[j])
        alpha = 0
        if i != j :
            for k in range(len(words[j])) :
                print("words[j]: ", words[j], "   words[i][k]: ", words[i][k])
                alpha += words[j].count(words[i][k])
        print("alpha: ", alpha)
        if alpha == 2 :
            graph[i].append(j)
        print("--------------------------------------------------------------")
# Out:
# ===================================
# words[i]:  hit
# words[j]:  hit
# alpha:  0
# --------------------------------------------------------------
# words[j]:  hot
# words[j]:  hot    words[i][k]:  h
# words[j]:  hot    words[i][k]:  i
# words[j]:  hot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  dot
# words[j]:  dot    words[i][k]:  h
# words[j]:  dot    words[i][k]:  i
# words[j]:  dot    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  dog
# words[j]:  dog    words[i][k]:  h
# words[j]:  dog    words[i][k]:  i
# words[j]:  dog    words[i][k]:  t
# alpha:  0
# --------------------------------------------------------------
# words[j]:  lot
# words[j]:  lot    words[i][k]:  h
# words[j]:  lot    words[i][k]:  i
# words[j]:  lot    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  log
# words[j]:  log    words[i][k]:  h
# words[j]:  log    words[i][k]:  i
# words[j]:  log    words[i][k]:  t
# alpha:  0
# --------------------------------------------------------------
# words[j]:  cog
# words[j]:  cog    words[i][k]:  h
# words[j]:  cog    words[i][k]:  i
# words[j]:  cog    words[i][k]:  t
# alpha:  0
# --------------------------------------------------------------
# ===================================
# words[i]:  hot
# words[j]:  hit
# words[j]:  hit    words[i][k]:  h
# words[j]:  hit    words[i][k]:  o
# words[j]:  hit    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  hot
# alpha:  0
# --------------------------------------------------------------
# words[j]:  dot
# words[j]:  dot    words[i][k]:  h
# words[j]:  dot    words[i][k]:  o
# words[j]:  dot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  dog
# words[j]:  dog    words[i][k]:  h
# words[j]:  dog    words[i][k]:  o
# words[j]:  dog    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  lot
# words[j]:  lot    words[i][k]:  h
# words[j]:  lot    words[i][k]:  o
# words[j]:  lot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  log
# words[j]:  log    words[i][k]:  h
# words[j]:  log    words[i][k]:  o
# words[j]:  log    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  cog
# words[j]:  cog    words[i][k]:  h
# words[j]:  cog    words[i][k]:  o
# words[j]:  cog    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# ===================================
# words[i]:  dot
# words[j]:  hit
# words[j]:  hit    words[i][k]:  d
# words[j]:  hit    words[i][k]:  o
# words[j]:  hit    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  hot
# words[j]:  hot    words[i][k]:  d
# words[j]:  hot    words[i][k]:  o
# words[j]:  hot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  dot
# alpha:  0
# --------------------------------------------------------------
# words[j]:  dog
# words[j]:  dog    words[i][k]:  d
# words[j]:  dog    words[i][k]:  o
# words[j]:  dog    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  lot
# words[j]:  lot    words[i][k]:  d
# words[j]:  lot    words[i][k]:  o
# words[j]:  lot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  log
# words[j]:  log    words[i][k]:  d
# words[j]:  log    words[i][k]:  o
# words[j]:  log    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  cog
# words[j]:  cog    words[i][k]:  d
# words[j]:  cog    words[i][k]:  o
# words[j]:  cog    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# ===================================
# words[i]:  dog
# words[j]:  hit
# words[j]:  hit    words[i][k]:  d
# words[j]:  hit    words[i][k]:  o
# words[j]:  hit    words[i][k]:  g
# alpha:  0
# --------------------------------------------------------------
# words[j]:  hot
# words[j]:  hot    words[i][k]:  d
# words[j]:  hot    words[i][k]:  o
# words[j]:  hot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  dot
# words[j]:  dot    words[i][k]:  d
# words[j]:  dot    words[i][k]:  o
# words[j]:  dot    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# words[j]:  dog
# alpha:  0
# --------------------------------------------------------------
# words[j]:  lot
# words[j]:  lot    words[i][k]:  d
# words[j]:  lot    words[i][k]:  o
# words[j]:  lot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  log
# words[j]:  log    words[i][k]:  d
# words[j]:  log    words[i][k]:  o
# words[j]:  log    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# words[j]:  cog
# words[j]:  cog    words[i][k]:  d
# words[j]:  cog    words[i][k]:  o
# words[j]:  cog    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# ===================================
# words[i]:  lot
# words[j]:  hit
# words[j]:  hit    words[i][k]:  l
# words[j]:  hit    words[i][k]:  o
# words[j]:  hit    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  hot
# words[j]:  hot    words[i][k]:  l
# words[j]:  hot    words[i][k]:  o
# words[j]:  hot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  dot
# words[j]:  dot    words[i][k]:  l
# words[j]:  dot    words[i][k]:  o
# words[j]:  dot    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  dog
# words[j]:  dog    words[i][k]:  l
# words[j]:  dog    words[i][k]:  o
# words[j]:  dog    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# words[j]:  lot
# alpha:  0
# --------------------------------------------------------------
# words[j]:  log
# words[j]:  log    words[i][k]:  l
# words[j]:  log    words[i][k]:  o
# words[j]:  log    words[i][k]:  t
# alpha:  2
# --------------------------------------------------------------
# words[j]:  cog
# words[j]:  cog    words[i][k]:  l
# words[j]:  cog    words[i][k]:  o
# words[j]:  cog    words[i][k]:  t
# alpha:  1
# --------------------------------------------------------------
# ===================================
# words[i]:  log
# words[j]:  hit
# words[j]:  hit    words[i][k]:  l
# words[j]:  hit    words[i][k]:  o
# words[j]:  hit    words[i][k]:  g
# alpha:  0
# --------------------------------------------------------------
# words[j]:  hot
# words[j]:  hot    words[i][k]:  l
# words[j]:  hot    words[i][k]:  o
# words[j]:  hot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  dot
# words[j]:  dot    words[i][k]:  l
# words[j]:  dot    words[i][k]:  o
# words[j]:  dot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  dog
# words[j]:  dog    words[i][k]:  l
# words[j]:  dog    words[i][k]:  o
# words[j]:  dog    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# words[j]:  lot
# words[j]:  lot    words[i][k]:  l
# words[j]:  lot    words[i][k]:  o
# words[j]:  lot    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# words[j]:  log
# alpha:  0
# --------------------------------------------------------------
# words[j]:  cog
# words[j]:  cog    words[i][k]:  l
# words[j]:  cog    words[i][k]:  o
# words[j]:  cog    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# ===================================
# words[i]:  cog
# words[j]:  hit
# words[j]:  hit    words[i][k]:  c
# words[j]:  hit    words[i][k]:  o
# words[j]:  hit    words[i][k]:  g
# alpha:  0
# --------------------------------------------------------------
# words[j]:  hot
# words[j]:  hot    words[i][k]:  c
# words[j]:  hot    words[i][k]:  o
# words[j]:  hot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  dot
# words[j]:  dot    words[i][k]:  c
# words[j]:  dot    words[i][k]:  o
# words[j]:  dot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  dog
# words[j]:  dog    words[i][k]:  c
# words[j]:  dog    words[i][k]:  o
# words[j]:  dog    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# words[j]:  lot
# words[j]:  lot    words[i][k]:  c
# words[j]:  lot    words[i][k]:  o
# words[j]:  lot    words[i][k]:  g
# alpha:  1
# --------------------------------------------------------------
# words[j]:  log
# words[j]:  log    words[i][k]:  c
# words[j]:  log    words[i][k]:  o
# words[j]:  log    words[i][k]:  g
# alpha:  2
# --------------------------------------------------------------
# words[j]:  cog
# alpha:  0
# --------------------------------------------------------------

# %%
print(graph)
# Out:
# [[1], [0, 2, 4], [1, 3, 4], [2, 5, 6], [1, 2, 5], [3, 4, 6], [3, 5]]

# %%
def DFS_rec(graph, root, visited=None) :
    if visited == None :
        visited = []
        
    visited.append(root)

    for node in graph[root] :
        if not node in visited :
            print("node: ", node)
            DFS_rec(graph, node, visited)

    return visited

# %%
DFS_rec(graph, 0, visited)
# Out:
# [0, 'hot', 0, 1, 2, 3, 5, 4, 6, 0]
